# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlist:
    def __init__(self):
        self.head=None
        
        
    def print_list(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
    
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node

    def delete_node(self,key):
        cur_node=self.head
        if cur_node and cur_node.data==key:
            self.head=cur_node.next
            cur_node=None
            return
        
        prev=None
        while cur_node and cur_node.data!=key:
            prev=cur_node
            cur_node=cur_node.next
        if cur_node is None:
            return
        prev.next=cur_node.next
        cur_node=None    
        
llist=linkedlist()
llist.append('A')
llist.append('B')
llist.append('v')
llist.append('d')
llist.append('7')
llist.delete_node('B')
llist.print_list()
# Out:
# A
# v
# d
# 7

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linkedlis:
    def __init__(self):
        self.head=None
    
    def print_list(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
    
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node

# %%
l=linkedlis()
l.append('A')
l.append('B')
l.append('c')
l.print_list()
# Out:
# A
# B
# c

# %%
class Node():
    def __init__(self,data,next=None):
        self.data=data
        self.next=None
class linkedl:
    def __init__(self):
        self.head=None
        
    def append(self,data):
        new_node=Node(data)
        
        if self.head is None:
            self.head=new_node
            
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node
        
    def print_(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next






















l=linkedl()
l.append('A')
l.append('B')
l.append('D')
l.print_()
# Out:
# A
# B
# D

# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
        
class linked():
    def __init__(self):
        self.head=None
        
    def append(self,data):
        newnode=Node(data)
        if self.head is None:
            self.head=newnode
            return
        last=self.head
        while last.next:
            last=last.next
        last.next=newnode    
        
    def print_(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
    
    def pepand(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
        
l=linked()
l.append('A')
l.append('B')
l.append('e')
l.pepand('g')
l.print_()
# Out:
# g
# A
# B
# e

# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
        
class Lin():
    def __init__(self):
        self.head=None
        
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
            
        last_node.next=new_node
        
    def print__(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
    
    
    def prepand(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
    
    def insert_afer_node(self,prev_node,data):
        if not prev_node:
            print('previous node is not in the list')
            return
        new_node=Node(data)
        new_node.next=prev_node.next
        prev_node.next=new_node
        
l=Lin()
l.append('A')
l.append('B')
l.append('e')
l.prepand('f')
l.insert_afer_node(l.head.next.next,'k')
l.print__()
# Out:
# f
# A
# B
# k
# e

# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
class linkedlist():
    def __init__(self):
        self.head=None
        
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node
        
        
    def print_(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
            
    def prepend(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
        
    def insert_node_afternode(self,prev_node,data):
        if not prev_node:
            print('previous node is not here')
        
            return
        new_node=Node(data)
        new_node.next=prev_node.next
        prev_node.next=new_node
        
        
        
L=linkedlist()
L.append("A")
L.append('B')
L.prepend(0)
L.insert_node_afternode(L.head,'k')
L.print_()
# Out:
# 0
# k
# A
# B

# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
class Linked():
    def __init__(self):
        self.head=None
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node
    
    def prepand(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
    def prit_(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
            
    def insert_pre(self,pre_node,data):
        if not pre_node:
            print('pre node not here')
            return
    
        new_node=Node(data)
        new_node.next=pre_node.next
        pre_node.next=new_node
L=Linked()
L.append("A")
L.append('B')
L.prepand('c')
L.insert_pre(L.head.next,'k')
L.prit_()
# Out:
# c
# A
# k
# B

# %%
class Node():
    def __init__(self,data):
        self.data=data
        self.next=None
class Linked():
    def __init__(self):
        self.head=None
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node
   
    def print__(self):
        cur_node=self.head
        while cur_node:
            print(cur_node.data)
            cur_node=cur_node.next
            
    def prepand(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
        
        
    def insert(self,prev_node,data):
        if not prev_node:
            print('not ')
            return
        new_node=Node(data)
        new_node.next=prev_node.next
        prev_node.next=new_node
        
    def delete_node(self,key):
        cur_node=self.head
        if cur_node and cur_node.data==key:
            self.head=cur_node.next
            cur_node=None
            return
        
        prev=None
        while cur_node and cur_node.data!=key:
            prev=cur_node
            cur_node=cur_node.next
        if cur_node is None:
            return
        prev.next=cur_node.next
        cur_node=None        
        
        
        
L=Linked()
L.append("A")
L.append('B')
#L.prepand('c')
#L.insert(L.head.next,'k')
L.delete_node('B')
L.print__()
# Out:
# A

# %%
class Node:
    
    def __init__(self,data):
        self.data=data
        self.next=None
        
class Linked():
    def __init__(self):
        self.head=None
        
    def append(self,data):
        new_node=Node(data)
        if self.head is None:
            self.head=new_node
            return
        last_node=self.head
        while last_node.next:
            last_node=last_node.next
        last_node.next=new_node
        
    def pri(self):
        cur=self.head
        while cur:
            print(cur.data)
            cur=cur.next
        
    def prepand(self,data):
        new_node=Node(data)
        new_node.next=self.head
        self.head=new_node
    def insert_after(self,prev,data):
        if not prev:
            print('not')
            return
        new_node=Node(data)
        new_node.next=prev.next
        prev.next=new_node
        
        
L=Linked()
L.append('A')
L.append('B')
L.prepand('c')
L.insert_after(L.head,'j')
L.pri()
# Out:
# c
# j
# A
# B
